# %% [markdown]
# ## h. Hacer el histograma comparativo (hist_comparativo)
#
# - #### **Objetivos :**
#     Si hay más de un conjunto de datos mostrar, crear y guardar un histograma combinado de ellos con los números de clases y colores indicado.
#
#     Tenga en cuenta que:
#     - El color de las barras debe tener una transparencia del 50%.
#     - El histograma debe tener título "Histograma Comparativo"
#     - El eje "x" y "y" deben titularse "Datos", "Frecuencia absoluta" respectivamente.
#     - El eje "y" debe tener una maya principal y una secundaria.
#     - El gráfico debe tener una leyenda ubicada en el mejor lugar posible.

# %% [markdown]
# - #### Entradas:

# %%
# 1. l_data: Lista con las lista de datos convertidos a enteros, de todos los archivos inidcados en el archivo de entrada.
l_data=[[62.2, 70.9, 70.0, 58.3, 56.0, 81.9, 73.2, 75.4, 63.1, 78.8, 65.6, 76.8, 59.9, 58.5, 65.5, 78.8, 57.6, 80.0, 76.5, 52.2, 75.0, 58.5, 70.0, 71.9, 69.3, 58.7, 74.2, 77.5, 76.0, 63.3, 65.7, 82.4, 84.2, 79.9, 66.7, 59.9, 72.8, 65.9, 72.3, 68.9, 48.8, 64.9, 56.7, 66.6, 76.6, 98.6, 68.1, 79.7, 82.8, 50.6, 70.2, 85.8, 80.6, 67.6, 61.6, 64.6, 57.3, 85.0, 73.3, 64.2, 63.1, 79.2, 63.6, 81.1, 44.0, 64.0, 82.0, 57.5, 76.0, 68.6, 60.2, 79.3, 60.4, 76.4, 80.9, 70.9, 76.2, 67.0, 86.5, 83.5, 67.8, 76.2, 70.0, 65.7, 80.8, 83.9, 83.0, 68.2, 66.0, 72.7, 75.6, 72.6, 67.0, 66.7, 38.8, 85.8, 72.7, 74.6, 59.3, 73.6, 70.1, 52.7, 76.6, 71.3, 77.3, 55.2, 73.7, 72.8, 57.0, 51.3, 82.6, 77.5, 71.3, 84.9, 83.5, 75.5, 85.5, 57.4, 62.5, 72.5, 76.1, 70.4, 62.4, 73.5, 88.4, 76.0, 66.7, 89.0, 76.8, 84.8, 64.7, 73.3, 61.1, 62.1, 54.7, 45.6, 72.9, 56.2, 62.0, 60.2, 61.1, 69.6, 69.1, 67.2, 90.5, 64.5, 69.4, 70.3, 63.3, 79.2, 71.6, 64.4, 75.2, 74.7, 68.9, 85.3, 76.9, 63.3, 55.9, 52.3, 61.1, 67.1, 73.8, 70.8, 70.1, 85.5, 75.2, 66.4, 78.5, 53.5, 66.0, 68.3, 76.9, 62.6, 67.5, 61.4, 76.0, 67.8, 61.2, 67.7, 57.4, 64.5, 82.1, 72.8, 69.8, 57.4, 82.6, 73.0, 61.1, 76.0, 51.3, 52.8, 76.8, 60.8, 45.9, 60.1, 55.0, 66.0, 61.1, 55.5, 77.0, 87.5, 80.7, 78.0, 56.6, 83.7, 77.4, 82.6, 65.1, 74.1, 60.2, 56.5, 60.5, 74.2,
, 30.3, 28.1, 28.6, 31.7, 31.4, 30.2, 36.0, 30.9, 31.3, 29.9, 35.5, 29.3, 34.4, 31.6, 30.4, 28.1, 36.5, 32.9, 32.4, 31.1, 32.4, 39.3, 31.3, 28.7, 35.5, 33.1, 30.8, 27.5, 29.5, 32.6, 32.6, 27.6, 30.4, 29.5, 34.2, 29.6, 29.5, 35.8, 33.9, 34.2, 26.4, 28.5, 37.8, 27.1, 32.7, 32.8, 31.2, 30.2, 24.0, 29.4, 30.1, 33.3, 35.7, 34.1, 28.0, 33.8, 36.0, 30.7, 30.4, 32.3, 29.5, 28.2, 31.6, 28.0, 27.7, 36.4, 31.6, 30.6, 35.8, 32.0, 32.4, 34.9, 28.1, 22.8, 30.7, 32.4, 38.3, 30.4, 38.0, 34.6, 33.5, 31.9, 29.5, 30.6, 28.5, 25.7, 33.3, 28.1, 33.3, 30.4, 31.2, 30.6, 28.7, 29.8]]
# 2. l_k: Lista con los numero de clase indicados en el archivo de entrada.
l_k= [7, 7]
# 3. l_colores: Lista con los colores indicados en el archivo de entrada o elegidos aleatoriamente según sea el caso.
l_colores=['dodgerblue','teal']
# 4. l_archivo: Lista con los archivos de datos indicados en el archivo de entrada.
l_archivos= ['Ej_Temp_Ad.txt', 'Ej_Temp_Llen.txt'] 
# 5. archivo_entradas: Nombre del archivo de entradas.
archivo_entradas='Ej_Entradas.txt'

# %% [markdown]
# - #### **Salidas :**
#
# **1. Histograma_Comparativo:** Imagen .png con los histogramas de los colores indicados.
#
# - #### **Código :**
# Complete la función para convertir las entradas en las salidas, ingrese al [material de apoyo](#material "Ir al material de apoyo") para ver los ejemplos que lo pueden guiar, una vez terminada ejecútela y compare sus resultados con las salidas del [ejemplo](../../../Ejemplo/Ej_Monitoreo_de_Temperaturas.ipynb).

# %%
# Importar aquí los módulos necesarios

# h. Hacer el histograma comparativo
def hist_comparativo (l_data,l_k,l_colores,l_archivos): # Crear la función frecuencias con parámetros de entrada: lista de clases, lista de datos, archivo de datos y color del gráfico.
    # Escriba aquí el código:
    
    return None # No devolver nada

# %% [markdown]
# - #### **Prueba :** <a id='prueba'></a>
# Si la carpeta Resultados no existe créela en la misma ubicación de este notebook, luego ejecute la celda de entradas y la siguiente celda, finalmente compruebe si el archivo Histograma_Comparativo.png fue creado correctamente, si es así pase la función [aquí](../Tabla_de_Frecuencias.py)

# %%
# Prueba de salidas
hist_comparativo (l_data,l_k,l_colores,l_archivos)

# %% [markdown]
# ## Material de Apoyo <a id='material'></a>

# %% [markdown]
# - [Histograma Comparativo](../../../../../8_Graficos/8_Graficos.ipynb#Min-eje_Histograma_Comparativo "Ir al capítulo de Estructuras de datos")

# %% [markdown]
# ---
# | [**Atrás**](../Plantilla_TF.ipynb "Volver a la plantilla del programa principal")|
# | :--------: |
