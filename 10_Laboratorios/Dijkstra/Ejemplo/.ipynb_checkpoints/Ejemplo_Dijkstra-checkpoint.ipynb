# %% [markdown]
# <a id="ejemplo"></a>
# ![Fig3_Encabezado.png](../../../Fig3_Encabezado.png)
#
# ---------------------

# %% [markdown]
# ## Ejemplo - Dijkstra

# %% [markdown]
# - Suponga que tiene el siguiente sistema de redes:
#
# ![Red_1](Red_1.png "Ejemplo: Red - Fuente: Curso Implementación de Algoritmos de Ingeniería Insdustrial")
#
# - Esta red se puede resumir en una matriz de la siguiente manera:
# ![matriz_1](Matriz_1.png "Ejemplo: Matríz asociada a la red - Fuente: Curso Implementación de Conmputacional de Algoritmos de Ingeniería Insdustrial")
#
# - La matriz anterior es guardada en el archivo [Ej_Dijkstra.txt](Ej_Dijkstra.txt)

# %% [markdown]
# - #### **Solución**
#     Los pasos para encontrar la ruta más corta desde el punto 'O' hasta el punto 'T' son los siguientes.
#
# |Nodos|Nodos Resueltos|N. Candidatos|
# | :--------: | :--------: | :--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|
#
# 1. **Considerar el punto de partida como resuelto.**
#
# |Nodos|Nodos Resueltos|N. Candidatos|
# | :--------: | :--------: | :--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|
# |A, B, C, D, E, F, G, H, T|O|-|
#
# 2. **Identificar los nodos candidatos:** Son los puntos inmediatamente conectados con los nodos resueltos y deben ser identificados con el punto desde donde es evaluado y su distancia al punto de origen.
#
# Los candidatos son:
# - 'A', evaluado desde 'O' a una distancia del origen de 5.
# - 'C', evaluado desde 'O' a una distancia del origen de 7.
# - 'D', evaluado desde 'O' a una distancia del origen de 11.
#
# |Nodos|Nodos Resueltos|N. Candidatos|
# | :--------: | :--------: | :--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|
# |A, B, C, D, E, F, G, H, T|O|A(O,5); C(O,7); D(O,11)|
#
# 3. **Pasar a la columna de nodos resueltos el nodo candidato con menor distancia.**
#
# |Nodos|Nodos Resueltos|N. Candidatos|
# | :--------: | :--------: | :--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|
# |A, B, C, D, E, F, G, H, T|O|A(O,5); D(O,11)|
# |B, C, D, E, F, G, H, T|O; A(O,5)|C(O,7); D(O,11)|
#
# 4. **Repetir los pasos 2 y 3 hasta que el nodo de destino (en este caso el T) esté resuelto.**
#
# ###### **Nota:** Si se requiere saber la ruta más corta hacia todos los puntos, se deben resolver todos los nodos.
#
# Los candidatos son:
# - 'C', evaluado desde 'O' a una distancia del origen de 7.
# - 'D', evaluado desde 'O' a una distancia del origen de 11.
# - 'C', evaluado desde 'A' a una distancia del origen de 9.
# - 'B', evaluado desde 'A' a una distancia del origen de 11.
#
# |Nodos|Nodos Resueltos|N. Candidatos|
# | :--------: | :--------: | :--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|
# |A, B, C, D, E, F, G, H, T|O|A(O,5); C(O,7); D(O,11)|
# |B, C, D, E, F, G, H, T|O; A(O,5)|C(O,7); D(O,11)|
# |B, C, D, E, F, G, H, T|O; A(O,5)|C(O,7); D(O,11); C(A,9); B(A,11)|
#
# - El nodo a menor distancia del origen es 'C' evaluado desde O.
#
# |Nodos|Nodos Resueltos|N. Candidatos|
# | :--------: | :--------: | :--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|
# |A, B, C, D, E, F, G, H, T|O|A(O,5); C(O,7); D(O,11)|
# |B, C, D, E, F, G, H, T|O; A(O,5)|C(O,7); D(O,11)|
# |B, C, D, E, F, G, H, T|O; A(O,5)|C(O,7); D(O,11); C(A,9); B(A,11)|
# |B, D, E, F, G, H, T|O; A(O,5); C(O,7)| D(O,11); C(A,9); B(A,11)|
#
# Los candidatos son:
# - 'D', evaluado desde 'O' a una distancia del origen de 11.
# - 'B', evaluado desde 'A' a una distancia del origen de 11.
# - 'B', evaluado desde 'C' a una distancia del origen de 16.
# - 'D', evaluado desde 'C' a una distancia del origen de 10.
#
# |Nodos|Nodos Resueltos|N. Candidatos|
# | :--------: | :--------: | :--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|
# |A, B, C, D, E, F, G, H, T|O|A(O,5); C(O,7); D(O,11)|
# |B, C, D, E, F, G, H, T|O; A(O,5)|C(O,7); D(O,11)|
# |B, C, D, E, F, G, H, T|O; A(O,5)|C(O,7); D(O,11); C(A,9); B(A,11)|
# |B, D, E, F, G, H, T|O; A(O,5); C(O,7)| D(O,11); C(A,9); B(A,11)|
# |B, D, E, F, G, H, T|O; A(O,5); C(O,7)| D(O,11); B(A,11); B(C,16); D(C,10)|
#
# - El nodo a menor distancia del origen es 'D' evaluado desde C.
#
# |Nodos|Nodos Resueltos|N. Candidatos|
# | :--------: | :--------: | :--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|
# |A, B, C, D, E, F, G, H, T|O|A(O,5); C(O,7); D(O,11)|
# |B, C, D, E, F, G, H, T|O; A(O,5)|C(O,7); D(O,11)|
# |B, C, D, E, F, G, H, T|O; A(O,5)|C(O,7); D(O,11); C(A,9); B(A,11)|
# |B, D, E, F, G, H, T|O; A(O,5); C(O,7)| D(O,11); C(A,9); B(A,11)|
# |B, D, E, F, G, H, T|O; A(O,5); C(O,7)| D(O,11); B(A,11); B(C,16); D(C,10)|
# |B, E, F, G, H, T|O; A(O,5); C(O,7); D(C,10)| D(O,11); B(A,11); B(C,16)|
#
# Los candidatos son:
# - 'B', evaluado desde 'A' a una distancia del origen de 11.
# - 'B', evaluado desde 'C' a una distancia del origen de 16.
# - 'E', evaluado desde 'D' a una distancia del origen de 18.
#
# |Nodos|Nodos Resueltos|N. Candidatos|
# | :--------: | :--------: | :--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|
# |A, B, C, D, E, F, G, H, T|O|A(O,5); C(O,7); D(O,11)|
# |B, C, D, E, F, G, H, T|O; A(O,5)|C(O,7); D(O,11)|
# |B, C, D, E, F, G, H, T|O; A(O,5)|C(O,7); D(O,11); C(A,9); B(A,11)|
# |B, D, E, F, G, H, T|O; A(O,5); C(O,7)| D(O,11); C(A,9); B(A,11)|
# |B, D, E, F, G, H, T|O; A(O,5); C(O,7)| D(O,11); B(A,11); B(C,16); D(C,10)|
# |B, E, F, G, H, T|O; A(O,5); C(O,7); D(C,10)| D(O,11); B(A,11); B(C,16)|
# |B, E, F, G, H, T|O; A(O,5); C(O,7); D(C,10)| B(A,11); B(C,16); E(D,18)|
#
# - El nodo a menor distancia del origen es 'B' evaluado desde A.
#
# |Nodos|Nodos Resueltos|N. Candidatos|
# | :--------: | :--------: | :--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|
# |A, B, C, D, E, F, G, H, T|O|A(O,5); C(O,7); D(O,11)|
# |B, C, D, E, F, G, H, T|O; A(O,5)|C(O,7); D(O,11)|
# |B, C, D, E, F, G, H, T|O; A(O,5)|C(O,7); D(O,11); C(A,9); B(A,11)|
# |B, D, E, F, G, H, T|O; A(O,5); C(O,7)| D(O,11); C(A,9); B(A,11)|
# |B, D, E, F, G, H, T|O; A(O,5); C(O,7)| D(O,11); B(A,11); B(C,16); D(C,10)|
# |B, E, F, G, H, T|O; A(O,5); C(O,7); D(C,10)| D(O,11); B(A,11); B(C,16)|
# |B, E, F, G, H, T|O; A(O,5); C(O,7); D(C,10)| B(A,11); B(C,16); E(D,18)|
# |E, F, G, H, T|O; A(O,5); C(O,7); D(C,10); B(A,11)| B(C,16); E(D,18)|
#
# Los candidatos son:
# - 'E', evaluado desde 'D' a una distancia del origen de 18.
# - 'G', evaluado desde 'B' a una distancia del origen de 13.
# - 'T', evaluado desde 'B' a una distancia del origen de 17.
#
# |Nodos|Nodos Resueltos|N. Candidatos|
# | :--------: | :--------: | :--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|
# |A, B, C, D, E, F, G, H, T|O|A(O,5); C(O,7); D(O,11)|
# |B, C, D, E, F, G, H, T|O; A(O,5)|C(O,7); D(O,11)|
# |B, C, D, E, F, G, H, T|O; A(O,5)|C(O,7); D(O,11); C(A,9); B(A,11)|
# |B, D, E, F, G, H, T|O; A(O,5); C(O,7)| D(O,11); C(A,9); B(A,11)|
# |B, D, E, F, G, H, T|O; A(O,5); C(O,7)| D(O,11); B(A,11); B(C,16); D(C,10)|
# |B, E, F, G, H, T|O; A(O,5); C(O,7); D(C,10)| D(O,11); B(A,11); B(C,16)|
# |B, E, F, G, H, T|O; A(O,5); C(O,7); D(C,10)| B(A,11); B(C,16); E(D,18)|
# |E, F, G, H, T|O; A(O,5); C(O,7); D(C,10); B(A,11)|E(D,18); G(B,13); T(B,17)|
#
# - El nodo a menor distancia del origen es 'G' evaluado desde B.
#
# |Nodos|Nodos Resueltos|N. Candidatos|
# | :--------: | :--------: | :--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|
# |A, B, C, D, E, F, G, H, T|O|A(O,5); C(O,7); D(O,11)|
# |B, C, D, E, F, G, H, T|O; A(O,5)|C(O,7); D(O,11)|
# |B, C, D, E, F, G, H, T|O; A(O,5)|C(O,7); D(O,11); C(A,9); B(A,11)|
# |B, D, E, F, G, H, T|O; A(O,5); C(O,7)| D(O,11); C(A,9); B(A,11)|
# |B, D, E, F, G, H, T|O; A(O,5); C(O,7)| D(O,11); B(A,11); B(C,16); D(C,10)|
# |B, E, F, G, H, T|O; A(O,5); C(O,7); D(C,10)| D(O,11); B(A,11); B(C,16)|
# |B, E, F, G, H, T|O; A(O,5); C(O,7); D(C,10)| B(A,11); B(C,16); E(D,18)|
# |E, F, G, H, T|O; A(O,5); C(O,7); D(C,10); B(A,11)|E(D,18); G(B,13); T(B,17)|
# |E, F, H, T|O; A(O,5); C(O,7); D(C,10); B(A,11); G(B,13)|E(D,18); T(B,17)|
#
# Los candidatos son:
# - 'E', evaluado desde 'D' a una distancia del origen de 18.
# - 'T', evaluado desde 'B' a una distancia del origen de 17.
# - 'T', evaluado desde 'G' a una distancia del origen de 21.
# - 'F', evaluado desde 'G' a una distancia del origen de 16.
#
# |Nodos|Nodos Resueltos|N. Candidatos|
# | :--------: | :--------: | :--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|
# |A, B, C, D, E, F, G, H, T|O|A(O,5); C(O,7); D(O,11)|
# |B, C, D, E, F, G, H, T|O; A(O,5)|C(O,7); D(O,11)|
# |B, C, D, E, F, G, H, T|O; A(O,5)|C(O,7); D(O,11); C(A,9); B(A,11)|
# |B, D, E, F, G, H, T|O; A(O,5); C(O,7)| D(O,11); C(A,9); B(A,11)|
# |B, D, E, F, G, H, T|O; A(O,5); C(O,7)| D(O,11); B(A,11); B(C,16); D(C,10)|
# |B, E, F, G, H, T|O; A(O,5); C(O,7); D(C,10)| D(O,11); B(A,11); B(C,16)|
# |B, E, F, G, H, T|O; A(O,5); C(O,7); D(C,10)| B(A,11); B(C,16); E(D,18)|
# |E, F, G, H, T|O; A(O,5); C(O,7); D(C,10); B(A,11)|E(D,18); G(B,13); T(B,17)|
# |E, F, H, T|O; A(O,5); C(O,7); D(C,10); B(A,11); G(B,13)|E(D,18); T(B,17)|
# |E, F, H, T|O; A(O,5); C(O,7); D(C,10); B(A,11); G(B,13)|E(D,18); T(B,17), T(G,21),F(G,16)|
#
# - El nodo a menor distancia del origen es 'F' evaluado desde G.
#
# |Nodos|Nodos Resueltos|N. Candidatos|
# | :--------: | :--------: | :--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|
# |A, B, C, D, E, F, G, H, T|O|A(O,5); C(O,7); D(O,11)|
# |B, C, D, E, F, G, H, T|O; A(O,5)|C(O,7); D(O,11)|
# |B, C, D, E, F, G, H, T|O; A(O,5)|C(O,7); D(O,11); C(A,9); B(A,11)|
# |B, D, E, F, G, H, T|O; A(O,5); C(O,7)| D(O,11); C(A,9); B(A,11)|
# |B, D, E, F, G, H, T|O; A(O,5); C(O,7)| D(O,11); B(A,11); B(C,16); D(C,10)|
# |B, E, F, G, H, T|O; A(O,5); C(O,7); D(C,10)| D(O,11); B(A,11); B(C,16)|
# |B, E, F, G, H, T|O; A(O,5); C(O,7); D(C,10)| B(A,11); B(C,16); E(D,18)|
# |E, F, G, H, T|O; A(O,5); C(O,7); D(C,10); B(A,11)|E(D,18); G(B,13); T(B,17)|
# |E, F, H, T|O; A(O,5); C(O,7); D(C,10); B(A,11); G(B,13)|E(D,18); T(B,17)|
# |E, F, H, T|O; A(O,5); C(O,7); D(C,10); B(A,11); G(B,13)|E(D,18); T(B,17); T(G,21); F(G,16)|
# |E, H, T|O; A(O,5); C(O,7); D(C,10); B(A,11); G(B,13); F(G,16)|E(D,18); T(B,17); T(G,21)|
#
# Los candidatos son:
# - 'E', evaluado desde 'D' a una distancia del origen de 18.
# - 'T', evaluado desde 'B' a una distancia del origen de 17.
# - 'T', evaluado desde 'G' a una distancia del origen de 21.
# - 'E', evaluado desde 'F' a una distancia del origen de 21.
# - 'H', evaluado desde 'F' a una distancia del origen de 23.
#
# |Nodos|Nodos Resueltos|N. Candidatos|
# | :--------: | :--------: | :--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|
# |A, B, C, D, E, F, G, H, T|O|A(O,5); C(O,7); D(O,11)|
# |B, C, D, E, F, G, H, T|O; A(O,5)|C(O,7); D(O,11)|
# |B, C, D, E, F, G, H, T|O; A(O,5)|C(O,7); D(O,11); C(A,9); B(A,11)|
# |B, D, E, F, G, H, T|O; A(O,5); C(O,7)| D(O,11); C(A,9); B(A,11)|
# |B, D, E, F, G, H, T|O; A(O,5); C(O,7)| D(O,11); B(A,11); B(C,16); D(C,10)|
# |B, E, F, G, H, T|O; A(O,5); C(O,7); D(C,10)| D(O,11); B(A,11); B(C,16)|
# |B, E, F, G, H, T|O; A(O,5); C(O,7); D(C,10)| B(A,11); B(C,16); E(D,18)|
# |E, F, G, H, T|O; A(O,5); C(O,7); D(C,10); B(A,11)|E(D,18); G(B,13); T(B,17)|
# |E, F, H, T|O; A(O,5); C(O,7); D(C,10); B(A,11); G(B,13)|E(D,18); T(B,17)|
# |E, F, H, T|O; A(O,5); C(O,7); D(C,10); B(A,11); G(B,13)|E(D,18); T(B,17); T(G,21); F(G,16)|
# |E, H, T|O; A(O,5); C(O,7); D(C,10); B(A,11); G(B,13); F(G,16)|E(D,18); T(B,17); T(G,21)|
# |E, H, T|O; A(O,5); C(O,7); D(C,10); B(A,11); G(B,13); F(G,16)|E(D,18); T(B,17); T(G,21); E(F,21); H(F,23)|
#
# - El nodo a menor distancia del origen es 'T' evaluado desde B.
#
# |Nodos|Nodos Resueltos|N. Candidatos|
# | :--------: | :--------: | :--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|
# |A, B, C, D, E, F, G, H, T|O|A(O,5); C(O,7); D(O,11)|
# |B, C, D, E, F, G, H, T|O; A(O,5)|C(O,7); D(O,11)|
# |B, C, D, E, F, G, H, T|O; A(O,5)|C(O,7); D(O,11); C(A,9); B(A,11)|
# |B, D, E, F, G, H, T|O; A(O,5); C(O,7)| D(O,11); C(A,9); B(A,11)|
# |B, D, E, F, G, H, T|O; A(O,5); C(O,7)| D(O,11); B(A,11); B(C,16); D(C,10)|
# |B, E, F, G, H, T|O; A(O,5); C(O,7); D(C,10)| D(O,11); B(A,11); B(C,16)|
# |B, E, F, G, H, T|O; A(O,5); C(O,7); D(C,10)| B(A,11); B(C,16); E(D,18)|
# |E, F, G, H, T|O; A(O,5); C(O,7); D(C,10); B(A,11)|E(D,18); G(B,13); T(B,17)|
# |E, F, H, T|O; A(O,5); C(O,7); D(C,10); B(A,11); G(B,13)|E(D,18); T(B,17)|
# |E, F, H, T|O; A(O,5); C(O,7); D(C,10); B(A,11); G(B,13)|E(D,18); T(B,17); T(G,21); F(G,16)|
# |E, H, T|O; A(O,5); C(O,7); D(C,10); B(A,11); G(B,13); F(G,16)|E(D,18); T(B,17); T(G,21)|
# |E, H, T|O; A(O,5); C(O,7); D(C,10); B(A,11); G(B,13); F(G,16)|E(D,18); T(B,17); T(G,21); E(F,21); H(F,23)|
# |E, H|O; A(O,5); C(O,7); D(C,10); B(A,11); G(B,13); F(G,16);T(B,17)|E(D,18); T(G,21); E(F,21); H(F,23)|
#
# 5. **Armar la ruta:** Reconstruir la ruta Desde el punto final 'T' hasta el punto donde fue evaluado y así sucesivamente hasta llegar al punto inicial 'O': **--->** T(B,17), B(A,11), A(O,5)
#
#     Entonces la ruta más corta es O, A, B, T, con una distancia de 17.

# %% [markdown]
# ![Red_1s](Red_1s.png "Ejemplo: Solución - Fuente: Curso Implementación de Algoritmos de Ingeniería Industrial")

# %% [markdown]
# #### Resultados <a id="resultados"></a>
#
# 1. **Archivos en excel con los resultados:** Abra o descargue el archivo Resultados_Ej_Dijkstra.xlsx guardado en la carpeta Resultados.

# %% [markdown]
# ---
# | [**Home**](../Dijkstra.ipynb "Ir a la página principal del algoritmo")| - | [**Prácticas**](../Practicas/Practicas_Dijkstra.ipynb "Ir a la página de la prácticas")|
# | :--------: | :-------: | :--------: |
