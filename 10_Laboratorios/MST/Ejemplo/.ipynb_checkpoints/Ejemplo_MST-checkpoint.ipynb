# %% [markdown]
# ![Fig3_Encabezado.png](../../../Fig3_Encabezado.png)
#
# ---------------------

# %% [markdown]
# ## Ejemplo - MST

# %% [markdown]
# - Suponga que tiene el siguiente sistema de redes:
#
# ![Red_1](Red_1.png "Ejemplo: Red - Fuente: Curso Implementación de Algoritmos de Ingeniería Industrial")
#
# - Esta red se puede resumir en una matriz de la siguiente manera:
# ![matriz_1](Matriz_1.png "Ejemplo: Matriz asociada a la red - Fuente: Curso Implementación de Computacional de Algoritmos de Ingeniería Industrial")
#
# - La matriz anterior es guardada en el archivo [Ej_MST.txt](Ej_MST.txt)

# %% [markdown]
# - #### **Solución**
#
# La solución se puede encontrar partiendo desde cualquier nodo y seleccionando el nodo que esté a menor distancia hasta que todos los nodos estén conectados, por ejemplo:
#
# |Nodos|Nodos Conectados|Conexión|Distancia|
# | :--------: | :--------: | :--------: |:--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|-|
#
# **1.** Se va a partir desde el nodo 'O'
#
# |Nodos|Nodos Conectados|Conexión|Distancia|
# | :--------: | :--------: | :--------: |:--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|-|
# |A, B, C, D, E, F, G, H, T|O|-|-|
#
# **2.** Escoger el nodo **no** conectado más cercano a cualquiera de los nodos que ya lo estén. En este caso es 'A' a una distancia de 5.
#
# |Nodos|Nodos Conectados|Conexión|Distancia|
# | :--------: | :--------: | :--------: |:--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|-|
# |A, B, C, D, E, F, G, H, T|O|-|-|
# |B, C, D, E, F, G, H, T|O, A|O, A|5|
#
# **3.** Repetir el paso 2 hasta que todos los nodos estén conectados.
#
# - El nodo no conectado más cercano a 'O' es 'C' a una distancia de 7.
#     El nodo no conectado más cercano a 'A' es 'C' a una distancia de 4.
#     Por lo tanto, la siguiente conexión es 'A - C'
#
# |Nodos|Nodos Conectados|Conexión|Distancia|
# | :--------: | :--------: | :--------: |:--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|-|
# |A, B, C, D, E, F, G, H, T|O|-|-|
# |B, C, D, E, F, G, H, T|O, A|O, A|5|
# |B, D, E, F, G, H, T|O, A, C|A, C|4|
#
# - El nodo no conectado más cercano a 'O' es 'D' a una distancia de 11.
#     El nodo no conectado más cercano a 'A' es 'B' a una distancia de 6.
#     El nodo no conectado más cercano a 'C' es 'D' a una distancia de 3.
#     Por lo tanto, la siguiente conexión es 'A - C'
#
# |Nodos|Nodos Conectados|Conexión|Distancia|
# | :--------: | :--------: | :--------: |:--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|-|
# |A, B, C, D, E, F, G, H, T|O|-|-|
# |B, C, D, E, F, G, H, T|O, A|O, A|5|
# |B, D, E, F, G, H, T|O, A, C|A, C|4|
# |B, E, F, G, H, T|O, A, C, D|C, D|3|
#
# - Todos los nodos enlazados a 'O' están conectados.
#     El nodo no conectado más cercano a 'A' es 'B' a una distancia de 6.
#     El nodo no conectado más cercano a 'C' es 'B' a una distancia de 9.
#     El nodo no conectado más cercano a 'D' es 'E' a una distancia de 8.
#     Por lo tanto, la siguiente conexión es 'A - B'
#
# |Nodos|Nodos Conectados|Conexión|Distancia|
# | :--------: | :--------: | :--------: |:--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|-|
# |A, B, C, D, E, F, G, H, T|O|-|-|
# |B, C, D, E, F, G, H, T|O, A|O, A|5|
# |B, D, E, F, G, H, T|O, A, C|A, C|4|
# |B, E, F, G, H, T|O, A, C, D|C, D|3|
# |E, F, G, H, T|O, A, C, D, B|A, B|6|
#
# - Todos los nodos enlazados a 'A' están conectados.
#     Todos los nodos enlazados a 'C' están conectados.
#     El nodo no conectado más cercano a 'D' es 'E' a una distancia de 8.
#     El nodo no conectado más cercano a 'B' es 'G' a una distancia de 2.
#     Por lo tanto, la siguiente conexión es 'B - G'
#
# |Nodos|Nodos Conectados|Conexión|Distancia|
# | :--------: | :--------: | :--------: |:--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|-|
# |A, B, C, D, E, F, G, H, T|O|-|-|
# |B, C, D, E, F, G, H, T|O, A|O, A|5|
# |B, D, E, F, G, H, T|O, A, C|A, C|4|
# |B, E, F, G, H, T|O, A, C, D|C, D|3|
# |E, F, G, H, T|O, A, C, D, B|A, B|6|
# |E, F, H, T|O, A, C, D, B, G|B, G|2|
#
# - El nodo no conectado más cercano a 'D' es 'E' a una distancia de 8.
#     El nodo no conectado más cercano a 'B' es 'T' a una distancia de 6.
#     El nodo no conectado más cercano a 'G' es 'F' a una distancia de 3.
#     Por lo tanto, la siguiente conexión es 'G - F'
#
# |Nodos|Nodos Conectados|Conexión|Distancia|
# | :--------: | :--------: | :--------: |:--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|-|
# |A, B, C, D, E, F, G, H, T|O|-|-|
# |B, C, D, E, F, G, H, T|O, A|O, A|5|
# |B, D, E, F, G, H, T|O, A, C|A, C|4|
# |B, E, F, G, H, T|O, A, C, D|C, D|3|
# |E, F, G, H, T|O, A, C, D, B|A, B|6|
# |E, F, H, T|O, A, C, D, B, G|B, G|2|
# |E, H, T|O, A, C, D, B, G, F|G, F|3|
#
# - El nodo no conectado más cercano a 'D' es 'E' a una distancia de 8.
#     El nodo no conectado más cercano a 'B' es 'T' a una distancia de 6.
#     El nodo no conectado más cercano a 'G' es 'T' a una distancia de 8.
#     El nodo no conectado más cercano a 'F' es 'E' a una distancia de 5.
#     Por lo tanto, la siguiente conexión es 'F - E'
#
# |Nodos|Nodos Conectados|Conexión|Distancia|
# | :--------: | :--------: | :--------: |:--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|-|
# |A, B, C, D, E, F, G, H, T|O|-|-|
# |B, C, D, E, F, G, H, T|O, A|O, A|5|
# |B, D, E, F, G, H, T|O, A, C|A, C|4|
# |B, E, F, G, H, T|O, A, C, D|C, D|3|
# |E, F, G, H, T|O, A, C, D, B|A, B|6|
# |E, F, H, T|O, A, C, D, B, G|B, G|2|
# |E, H, T|O, A, C, D, B, G, F|G, F|3|
# |H, T|O, A, C, D, B, G, F, E|F, E|5|
#
# - Todos los nodos enlazados a 'D' están conectados.
#     El nodo no conectado más cercano a 'B' es 'T' a una distancia de 6.
#     El nodo no conectado más cercano a 'G' es 'T' a una distancia de 8.
#     El nodo no conectado más cercano a 'F' es 'H' a una distancia de 7.
#     El nodo no conectado más cercano a 'E' es 'H' a una distancia de 3.
#     Por lo tanto, la siguiente conexión es 'E - H'
#
# |Nodos|Nodos Conectados|Conexión|Distancia|
# | :--------: | :--------: | :--------: |:--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|-|
# |A, B, C, D, E, F, G, H, T|O|-|-|
# |B, C, D, E, F, G, H, T|O, A|O, A|5|
# |B, D, E, F, G, H, T|O, A, C|A, C|4|
# |B, E, F, G, H, T|O, A, C, D|C, D|3|
# |E, F, G, H, T|O, A, C, D, B|A, B|6|
# |E, F, H, T|O, A, C, D, B, G|B, G|2|
# |E, H, T|O, A, C, D, B, G, F|G, F|3|
# |H, T|O, A, C, D, B, G, F, E|F, E|5|
# |T|O, A, C, D, B, G, F, E, H|E, H|3|
#
# - Todos los nodos enlazados a 'F' están conectados.
#     Todos los nodos enlazados a 'E' están conectados.
#     El nodo no conectado más cercano a 'B' es 'T' a una distancia de 6.
#     El nodo no conectado más cercano a 'G' es 'T' a una distancia de 8.
#     El nodo no conectado más cercano a 'H' es 'T' a una distancia de 5.
#     Por lo tanto, la siguiente y última conexión es 'H - T'
#
# |Nodos|Nodos Conectados|Conexión|Distancia|
# | :--------: | :--------: | :--------: |:--------: |
# |O, A, B, C, D, E, F, G, H, T|-|-|-|
# |A, B, C, D, E, F, G, H, T|O|-|-|
# |B, C, D, E, F, G, H, T|O, A|O, A|5|
# |B, D, E, F, G, H, T|O, A, C|A, C|4|
# |B, E, F, G, H, T|O, A, C, D|C, D|3|
# |E, F, G, H, T|O, A, C, D, B|A, B|6|
# |E, F, H, T|O, A, C, D, B, G|B, G|2|
# |E, H, T|O, A, C, D, B, G, F|G, F|3|
# |H, T|O, A, C, D, B, G, F, E|F, E|5|
# |T|O, A, C, D, B, G, F, E, H|E, H|3|
# |-|O, A, C, D, B, G, F, E, H, T|H, T|5|
#
# **4.** Calcular la distancia total.
#
# $D_{total}=5+4+3+6+2+3+5+3+5=36$
#
# - **Solución**
#
# ![Red_1s](Red_1s.png "Ejemplo: Solución - Fuente: Curso Implementación de Algoritmos de Ingeniería Industrial")

# %% [markdown]
# #### Resultados <a id="resultados"></a>
#
# 1. **Archivos en Excel con los resultados:** Abra o descargue el archivo Resultados_Ej_MST.xlsx guardado en la carpeta Resultados.

# %% [markdown]
# ---
# | [**Home**](../MST.ipynb "Ir a la página principal del algoritmo")| - | [**Prácticas**](../Practicas/Practicas_MST.ipynb "Ir a la página de la prácticas")|
# | :--------: | :-------: | :--------: |
